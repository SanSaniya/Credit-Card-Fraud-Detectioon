# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 
from sklearn.preprocessing import StandardScaler
import joblib
import shap
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"dataset\creditcard.csv")

# %%
data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
# 0 -> legitimate data 
# 1 -> fraud data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.shape
# Out:
# (284807, 31)

# %%
data['Class'].value_counts() # imbalanced data
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
legit = data[data.Class==0]
fraud = data[data['Class']==1]

# %%
legit['Class'].value_counts() #verifies that it has only legit data with class==1
# Out:
# Class
# 0    284315
# Name: count, dtype: int64

# %%
fraud['Class'].value_counts()
# Out:
# Class
# 1    492
# Name: count, dtype: int64

# %%
fraud.shape
# Out:
# (492, 31)

# %%
legit.shape
# Out:
# (284315, 31)

# %%
legit_sample = legit.sample(n=492)
credited_card_df = pd.concat([legit_sample, fraud], axis = 0)

# %%
credited_card_df.shape
# Out:
# (984, 31)

# %%
credited_card_df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
credited_card_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      91656.432927 -0.109766 -0.006840 -0.008762  0.057688 -0.073185
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.098608  0.002651  0.029149 -0.021319  ... -0.042780 -0.016919
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.004215 -0.019635  0.014919 -0.025711  0.007580  0.029498 -0.011110
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       89.597012
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = credited_card_df.drop('Class', axis =1)
Y = credited_card_df['Class']

# %%
X.shape
# Out:
# (984, 30)

# %%
Y.shape
# Out:
# (984,)

# %%
X.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 91010    63273.0 -1.794616  2.831977 -0.657090  0.419994  0.003604 -1.259529
# 268636  163313.0  0.028330  0.456725 -0.367331 -0.591054  0.014857  0.741559
# 123593   76988.0 -2.489669 -1.446706  1.846780  1.817882  3.038452 -0.787738
# 155786  106385.0  0.873976 -1.356129 -0.547210  1.834594 -2.351143  0.592220
# 214057  139514.0  1.857992 -0.440578 -0.764167  0.334360 -0.252315  0.384539
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 91010   0.988968 -0.215609  1.045684  ...  1.284485 -0.114663  0.484454
# 268636 -0.316273  0.759139  0.293374  ...  0.014800  0.171347  0.336703
# 123593 -0.659263  0.126996 -1.457858  ...  0.294421  0.093745  0.120106
# 155786  0.877075 -0.160613  2.318671  ...  1.044063  0.350245  0.712472
# 214057 -0.873606  0.282923  1.014276  ...  0.013110 -0.003955 -0.012588
#
# ...

# %%
Y.head(5)
# Out:
# 91010     0
# 268636    0
# 123593    0
# 155786    0
# 214057    0
# Name: Class, dtype: int64

# %%
#now we split the data into train and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state = 2)

# %%
print(X_train.shape)
# Out:
# (787, 30)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = LogisticRegression(max_iter=100)
model.fit(X_train,Y_train)
ypred = model.predict(X_test)
# Out:
# C:\jnotebook\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_score(ypred, Y_test)
# Out:
# 0.9238578680203046

# %%
# Save the model
joblib.dump(model, "model.pkl")

# Save the scaler model
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
explainer = shap.Explainer(model, X_train_scaled) # initialize shap
shap_values = explainer(X_test_scaled) #x test will be explained

#creat pyplot
shap.summary_plot(shap_values, X_test, plot_type="bar")
